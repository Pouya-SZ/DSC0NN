# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
from scipy.io import loadmat

import time

import librosa

from tqdm import tqdm_notebook
import torch

from matplotlib.gridspec import GridSpec
import seaborn as sns
from torch.utils.data import DataLoader
import torchvision


from utils import plot_spk_rec, plot_mem_rec
from models import SNN, SpikingConvLayer, ReadoutLayer, SurrogateHeaviside, SpikingDenseLayer

from optim import RAdam

# %%
X_train_batch = torch.Tensor(70, 55, 33, 155)
yy_train_batch = np.zeros((70,))

# %%
#label 1 for the ictal segment

for i in range(20):
    yy_train_batch[i] = 1

# %%
Y_train_batch=torch.from_numpy(yy_train_batch)

# %%
for i in range (20):    
    data = loadmat('Patient_3/Patient_3_ictal_segment_%s.mat' %(i+1))
    Pdata=data['ictal_segment_%s' %(i+1)]
    PPdata=Pdata['data']
    Matrix=PPdata[0,0] 
    f, t, Sxx = signal.spectrogram(Matrix[:,:], fs=400,noverlap=32,scaling='spectrum',nperseg=64)
    X_train_batch[i,:]=torch.from_numpy(Sxx)
    
for i in range (50):   
    data = loadmat('Patient_3/Patient_3_interictal_segment_%s.mat' %(i+1))
    Pdata=data['interictal_segment_%s' %(i+1)]
    PPdata=Pdata['data']
    Matrix=PPdata[0,0] 
    f, t, Sxx = signal.spectrogram(Matrix[:,:], fs=400,noverlap=32,scaling='spectrum',nperseg=64)
    X_train_batch[(i+20),:]=torch.from_numpy(Sxx)

# %%
X_train_batch.shape
# Out:
# torch.Size([70, 55, 33, 155])

# %%
X_Valid_batch = torch.Tensor(30, 55, 33, 155)
yy_Valid_batch = np.zeros((30,))

# %%
#label 1 for the ictal segment

for i in range(10):
    yy_Valid_batch[i] = 1

# %%
Y_Valid_batch=torch.from_numpy(yy_Valid_batch)

# %%
# Data for training and testing the network are available at https://msel.mayo.edu/data.html under "Sz detection data clips" for Patient_3. 

for i in range (10):    
    data = loadmat('Patient_3/Patient_3_ictal_segment_%s.mat' %(i+21))
    Pdata=data['ictal_segment_%s' %(i+21)]
    PPdata=Pdata['data']
    Matrix=PPdata[0,0] 
    f, t, Sxx = signal.spectrogram(Matrix[:,:], fs=400,noverlap=32,scaling='spectrum',nperseg=64)
    X_Valid_batch[i,:]=torch.from_numpy(Sxx)
    
for i in range (20):   
    data = loadmat('Patient_3/Patient_3_interictal_segment_%s.mat' %(i+51))
    Pdata=data['interictal_segment_%s' %(i+51)]
    PPdata=Pdata['data']
    Matrix=PPdata[0,0] 
    f, t, Sxx = signal.spectrogram(Matrix[:,:], fs=400,noverlap=32,scaling='spectrum',nperseg=64)
    X_Valid_batch[(i+10),:]=torch.from_numpy(Sxx)

# %%
X_Valid_batch.shape
# Out:
# torch.Size([30, 55, 33, 155])

# %%
X_Test_batch = torch.Tensor(41, 55, 33, 155)
yy_Test_batch = np.zeros((41,))

# %%
#label 1 for the ictal segment

for i in range(27):
    yy_Test_batch[i] = 1

# %%
Y_Test_batch=torch.from_numpy(yy_Test_batch)

# %%
# Data for training and testing the network are available at https://msel.mayo.edu/data.html under "Sz detection data clips" for Patient_3. 

for i in range (27):    
    data = loadmat('Patient_3/Patient_3_ictal_segment_%s.mat' %(i+301))
    Pdata=data['ictal_segment_%s' %(i+301)]
    PPdata=Pdata['data']
    Matrix=PPdata[0,0] 
    f, t, Sxx = signal.spectrogram(Matrix[:,:], fs=400,noverlap=32,scaling='spectrum',nperseg=64)
    X_Test_batch[i,:]=torch.from_numpy(Sxx)
    
for i in range (14):   
    data = loadmat('Patient_3/Patient_3_interictal_segment_%s.mat' %(i+701))
    Pdata=data['interictal_segment_%s' %(i+701)]
    PPdata=Pdata['data']
    Matrix=PPdata[0,0] 
    f, t, Sxx = signal.spectrogram(Matrix[:,:], fs=400,noverlap=32,scaling='spectrum',nperseg=64)
    X_Test_batch[(i+27),:]=torch.from_numpy(Sxx)

# %%
X_Test_batch.shape
# Out:
# torch.Size([41, 55, 33, 155])

# %%
dtype = torch.float
device = torch.device("cuda:0")

# %%
spike_fn = SurrogateHeaviside.apply

w_init_std = 0.15


layers = []

in_channels = 55
out_channels = 32
kernel_size = (4,3)
dilation = (1,1)
nb_inputs = 155
nb_outputs = nb_inputs # padding mode is "same"
layers.append(SpikingConvLayer(nb_inputs, nb_outputs,
                 in_channels, out_channels, kernel_size, dilation,
                 spike_fn, w_init_mean=0., w_init_std=w_init_std))


in_channels = out_channels
out_channels = 32
kernel_size = (4,3)
dilation = (4,3)
nb_inputs = nb_outputs
nb_outputs = nb_inputs # padding mode is "same"
layers.append(SpikingConvLayer(nb_inputs, nb_outputs,
                 in_channels, out_channels, kernel_size, dilation,
                 spike_fn, w_init_mean=0., w_init_std=w_init_std))

in_channels = out_channels
out_channels = 32
kernel_size = (4,3)
dilation = (16,9)
nb_inputs = nb_outputs
nb_outputs = nb_inputs # padding mode is "same"
layers.append(SpikingConvLayer(nb_inputs, nb_outputs,
                 in_channels, out_channels, kernel_size, dilation,
                 spike_fn, w_init_mean=0., w_init_std=w_init_std, flatten_output=True))

# previous layer output has been flattened
nb_inputs = nb_outputs*out_channels
nb_outputs = 2 
time_reduction="mean" #mean or max
layers.append(ReadoutLayer(nb_inputs, nb_outputs,
                 w_init_mean=0., w_init_std=w_init_std, time_reduction=time_reduction))

snn = SNN(layers).to(device, dtype)

#X_batch, _ = next(iter(train_dataloader))

X_train_batch = X_train_batch.to(device, dtype)
snn(X_train_batch)

for i,l in enumerate(snn.layers):
    if isinstance(l, SpikingDenseLayer) or isinstance(l, SpikingConvLayer):
        print("Layer {}: average number of spikes={:.4f}".format(i,l.spk_rec_hist.mean()))
# Out:
# /home/pouya/anaconda3/lib/python3.7/site-packages/torch/cuda/__init__.py:135: UserWarning:
#     Found GPU2 GeForce GT 740 which is of cuda capability 3.0.
#     PyTorch no longer supports this GPU because it is too old.
#     The minimum cuda capability that we support is 3.5.
#
#   warnings.warn(old_gpu_warn % (d, name, major, capability[1]))
# Layer 0: average number of spikes=0.1925
# Layer 1: average number of spikes=0.1525
# Layer 2: average number of spikes=0.1073

# %%
nb_plt = 9
batch_size = 70

batch_idx = np.random.choice(batch_size, nb_plt, replace=False)

# Plotting spike trains or membrane potential
for i,l in enumerate(snn.layers):
    
    if isinstance(l, SpikingDenseLayer):
        spk_rec = l.spk_rec_hist
        plot_spk_rec(spk_rec, idx=batch_idx)
    elif isinstance(l, SpikingConvLayer):
        spk_rec = l.spk_rec_hist
        plot_spk_rec(spk_rec.sum(1), idx=batch_idx)
    else:
        mem_rec = l.mem_rec_hist
        plot_mem_rec(mem_rec, batch_idx)

# %%
Y_train_batch = torch.tensor(Y_train_batch, dtype=torch.long, device=device)   
Y_Test_batch = torch.tensor(Y_Test_batch, dtype=torch.long, device=device)classification
# Out:
# /home/pouya/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """Entry point for launching an IPython kernel.
# /home/pouya/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).

# %%
def train(model, params, optimizer, reg_loss_coef, nb_epochs, scheduler=None, warmup_epochs=0):
    
    log_softmax_fn = torch.nn.LogSoftmax(dim=1)
    loss_fn = torch.nn.NLLLoss()
    
    if warmup_epochs > 0:
        for g in optimizer.param_groups:
            g['lr'] /= len(X_train_batch)*warmup_epochs
        warmup_itr = 1
    
    hist = {'loss':[], 'valid_accuracy':[]}
    for e in range(nb_epochs):
        local_loss = []
        reg_loss = [[] for _ in range(len(model.layers)-1)]
        

           
        x_batch = X_train_batch.cuda()
        y_batch = Y_train_batch.cuda()
                
        output, loss_seq = model(x_batch)
        log_p_y = log_softmax_fn(output)
        loss_val = loss_fn(log_p_y, y_batch)
        local_loss.append(loss_val.item())
                
        for i,loss in enumerate(loss_seq[:-1]):
            reg_loss_val = reg_loss_coef*loss*(i+1)/len(loss_seq[:-1])
            loss_val += reg_loss_val
            reg_loss[i].append(reg_loss_val.item())
                    

        optimizer.zero_grad()
        loss_val.backward()
        torch.nn.utils.clip_grad_value_(model.parameters(), 5)
        optimizer.step()
        model.clamp()
                
        if e < warmup_epochs:
            for g in optimizer.param_groups:
                g['lr'] *= (warmup_itr+1)/(warmup_itr)
            warmup_itr += 1
                
        
                
        if scheduler is not None and e >= warmup_epochs:
            scheduler.step()
        
        mean_loss = np.mean(local_loss)
        hist['loss'].append(mean_loss)
        print("Epoch %i: loss=%.5f"%(e+1,mean_loss))
        
        for i,loss in enumerate(reg_loss):
            mean_reg_loss = np.mean(loss)
            print("Layer %i: reg loss=%.5f"%(i,mean_reg_loss))
            
        for i,l in enumerate(snn.layers[:-1]):
            print("Layer {}: average number of spikes={:.4f}".format(i,l.spk_rec_hist.mean()))
        
        valid_accuracy = compute_classification_accuracy(model)
        hist['valid_accuracy'].append(valid_accuracy)
        print("Validation accuracy=%.3f"%(valid_accuracy))
        
    return hist
        
def compute_classification_accuracy(model):
    accs = []
    
    with torch.no_grad():
          
        x_batch = X_Valid_batch.cuda()
        y_batch = Y_Valid_batch.cuda()
        output, _ = model(x_batch)
        _,am=torch.max(output,1) # argmax over output units
        tmp = np.mean((y_batch==am).detach().cpu().numpy()) # compare to labels
        accs.append(tmp)
       
    return np.mean(accs)

# %%
lr = 1e-3
weight_decay = 1e-5
reg_loss_coef = 0.1
nb_epochs = 20

params = [{'params':l.w, 'lr':lr, "weight_decay":weight_decay } for i,l in enumerate(snn.layers)]
params += [{'params':l.b, 'lr':lr} for i,l in enumerate(snn.layers)]
if snn.layers[-1].time_reduction == "mean":
    params += [{'params':l.beta, 'lr':lr} for i,l in enumerate(snn.layers[:-1])]
elif snn.layers[-1].time_reduction == "max":
    params += [{'params':l.beta, 'lr':lr} for i,l in enumerate(snn.layers)]
else:
    raise ValueError("Readout time recution should be 'max' or 'mean'")
    
optimizer = RAdam(params)
 
gamma = 0.85
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma, last_epoch=-1)

hist = train(snn, params, optimizer, reg_loss_coef, nb_epochs=nb_epochs,
                  scheduler=scheduler, warmup_epochs=1)
# Out:
# Epoch 1: loss=0.33352
# Layer 0: reg loss=0.00318
# Layer 1: reg loss=0.00384
# Layer 2: reg loss=0.00089
# Layer 0: average number of spikes=0.1907
# Layer 1: average number of spikes=0.1152
# Layer 2: average number of spikes=0.0177
# Validation accuracy=0.700
# Epoch 2: loss=0.33312
# Layer 0: reg loss=0.00318
# Layer 1: reg loss=0.00384
# Layer 2: reg loss=0.00089
# Layer 0: average number of spikes=0.1907
# Layer 1: average number of spikes=0.1152
# Layer 2: average number of spikes=0.0178
# Validation accuracy=0.700
# Epoch 3: loss=0.33288
# Layer 0: reg loss=0.00318
# Layer 1: reg loss=0.00384
# Layer 2: reg loss=0.00089
# Layer 0: average number of spikes=0.1907
# Layer 1: average number of spikes=0.1152
# Layer 2: average number of spikes=0.0178
# Validation accuracy=0.700
# Epoch 4: loss=0.30505
# Layer 0: reg loss=0.00318
# Layer 1: reg loss=0.00386
# Layer 2: reg loss=0.00096
# Layer 0: average number of spikes=0.1907
# Layer 1: average number of spikes=0.1157
# Layer 2: average number of spikes=0.0192
# Validation accuracy=0.700
# Epoch 5: loss=0.29175
# Layer 0: reg loss=0.00318
# Layer 1: reg loss=0.00387
# Layer 2: reg loss=0.00102
# Layer 0: average number of spikes=0.1907
# Layer 1: average number of spikes=0.1160
# Layer 2: average number of spikes=0.0204
# Validation accuracy=0.700
# Epoch 6: loss=0.27481
# Layer 0: reg loss=0.00318
# Layer 1: reg loss=0.00387
# Layer 2: reg loss=0.00106
# Layer 0: average number of spikes=0.1907
# Layer 1: average number of spikes=0.1162
# Layer 2: average number of spikes=0.0213
# Validation accuracy=0.700
# Epoch 7: loss=0.25488
# Layer 0: reg loss=0.00318
# Layer 1: reg loss=0.00391
# Layer 2: reg loss=0.00112
# Layer 0: average number of spikes=0.1907
# Layer 1: average number of spikes=0.1172
# Layer 2: average number of spikes=0.0225
# Validation accuracy=0.700
# Epoch 8: loss=0.23644
# Layer 0: reg loss=0.00318
# Layer 1: reg loss=0.00394
# Layer 2: reg loss=0.00118
# Layer 0: average number of spikes=0.1907
# Layer 1: average number of spikes=0.1182
# Layer 2: average number of spikes=0.0236
# Validation accuracy=0.700
# Epoch 9: loss=0.21311
# Layer 0: reg loss=0.00318
# Layer 1: reg loss=0.00398
# Layer 2: reg loss=0.00124
# Layer 0: average number of spikes=0.1907
# Layer 1: average number of spikes=0.1193
# Layer 2: average number of spikes=0.0248
# Validation accuracy=0.767
# Epoch 10: loss=0.19276
# Layer 0: reg loss=0.00318
# Layer 1: reg loss=0.00401
# Layer 2: reg loss=0.00130
# Layer 0: average number of spikes=0.1907
# Layer 1: average number of spikes=0.1204
# Layer 2: average number of spikes=0.0259
# Validation accuracy=0.833
# Epoch 11: loss=0.18066
# Layer 0: reg loss=0.00318
# Layer 1: reg loss=0.00405
# Layer 2: reg loss=0.00136
# Layer 0: average number of spikes=0.1908
# Layer 1: average number of spikes=0.1215
# Layer 2: average number of spikes=0.0272
# Validation accuracy=0.867
# Epoch 12: loss=0.16893
# Layer 0: reg loss=0.00318
# Layer 1: reg loss=0.00409
# Layer 2: reg loss=0.00143
# Layer 0: average number of spikes=0.1907
# Layer 1: average number of spikes=0.1226
# Layer 2: average number of spikes=0.0286
# Validation accuracy=0.900
# Epoch 13: loss=0.15333
# Layer 0: reg loss=0.00318
# Layer 1: reg loss=0.00412
# Layer 2: reg loss=0.00150
# Layer 0: average number of spikes=0.1906
# Layer 1: average number of spikes=0.1237
# Layer 2: average number of spikes=0.0300
# Validation accuracy=0.900
# Epoch 14: loss=0.14389
# Layer 0: reg loss=0.00317
# Layer 1: reg loss=0.00416
# Layer 2: reg loss=0.00157
# Layer 0: average number of spikes=0.1904
# Layer 1: average number of spikes=0.1247
# Layer 2: average number of spikes=0.0313
# Validation accuracy=0.933
# Epoch 15: loss=0.13116
# Layer 0: reg loss=0.00317
# Layer 1: reg loss=0.00419
# Layer 2: reg loss=0.00163
# Layer 0: average number of spikes=0.1902
# Layer 1: average number of spikes=0.1257
# Layer 2: average number of spikes=0.0326
# Validation accuracy=0.900
# Epoch 16: loss=0.12731
# Layer 0: reg loss=0.00317
# Layer 1: reg loss=0.00422
# Layer 2: reg loss=0.00169
# Layer 0: average number of spikes=0.1900
# Layer 1: average number of spikes=0.1265
# Layer 2: average number of spikes=0.0339
# Validation accuracy=0.900
# Epoch 17: loss=0.11767
# Layer 0: reg loss=0.00316
# Layer 1: reg loss=0.00424
# Layer 2: reg loss=0.00175
# Layer 0: average number of spikes=0.1898
# Layer 1: average number of spikes=0.1272
# Layer 2: average number of spikes=0.0350
# Validation accuracy=0.900
# Epoch 18: loss=0.11156
# Layer 0: reg loss=0.00316
# Layer 1: reg loss=0.00426
# Layer 2: reg loss=0.00180
# Layer 0: average number of spikes=0.1896
# Layer 1: average number of spikes=0.1278
# Layer 2: average number of spikes=0.0360
# Validation accuracy=0.900
# Epoch 19: loss=0.10631
# Layer 0: reg loss=0.00316
# Layer 1: reg loss=0.00428
# Layer 2: reg loss=0.00185
# Layer 0: average number of spikes=0.1895
# Layer 1: average number of spikes=0.1283
# Layer 2: average number of spikes=0.0370
# Validation accuracy=0.933
# Epoch 20: loss=0.10361
# Layer 0: reg loss=0.00316
# Layer 1: reg loss=0.00429
# Layer 2: reg loss=0.00189
# Layer 0: average number of spikes=0.1894
# Layer 1: average number of spikes=0.1288
# Layer 2: average number of spikes=0.0378
# Validation accuracy=0.933

# %%
def compute_test_accuracy(model):
    accs = []
    
    with torch.no_grad():
          
        x_batch = X_Test_batch.cuda()
        y_batch = Y_Test_batch.cuda()
        output, _ = model(x_batch)
        _,am=torch.max(output,1) # argmax over output units
        tmp = np.mean((y_batch==am).detach().cpu().numpy()) # compare to labels
        accs.append(tmp)
       
    return np.mean(accs)

test_accuracy = compute_test_accuracy(snn)
print("Test accuracy=%.3f"%(test_accuracy))
# Out:
# Test accuracy=0.976

# %%
x_batch = X_Test_batch.cuda()
y_batch = Y_Test_batch.cuda()
output, _ = snn(x_batch)
_,am=torch.max(output,1) # argmax over output units
Targets=y_batch.cpu().numpy()
Predictions=am.cpu().numpy()

# %%
from sklearn.metrics import confusion_matrix 
import itertools

# %%
cm = confusion_matrix(Targets, Predictions)

# %%
def plot_confusion_matrix(cm, classes,
                         normalize=False,
                         title='Confusion matrix',
                         cmap=plt.cm.Blues):
    
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
        
    print(cm)
    
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                horizontalalignment='center',
                color='white' if cm[i, j] > thresh else "black")
        
    plt.tight_layout()
    plt.ylabel('Actual Diagnosis')
    plt.xlabel('SNN Prediction')

# %%
cm_plot_labels = ['Seizure-free', 'Seizure']
plot_confusion_matrix(cm, cm_plot_labels, title='Confusion Matrix')
# Out:
# Confusion matrix, without normalization
# [[14  0]
#  [ 1 26]]
